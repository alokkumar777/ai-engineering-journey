# %%
dictionary = {
        'patient_id': 'p1004',
        'age': 56,
        'gender': 'Male',
        'diagnosis': 'Chronic Back Pain',
        'medications': ['Ibuprofen', 'Physical Therapy'],
        'last_visit_id': 'V2304',
    }  

set_keys = ['patient_id', 'age', 'gender', 'diagnosis', 'medications', 'last_visit_id']

"age" in dictionary
# Out:
# 56

# %%
set_keys = set([1, 2, 3, 4, 4])
set_keys
# Out:
# {1, 2, 3, 4}
