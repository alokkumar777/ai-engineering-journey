# %%
import pdb
def divided(a, b):
    # pdb.set_trace()
    breakpoint()
    return a / b
print((pdb))
divided(6, 2)
# Out:
# <module 'pdb' from 'c:\\Users\\HP\\AppData\\Local\\Programs\\Python\\Python312\\Lib\\pdb.py'>
# 3.0

# %%
import pdb
(pdb)
