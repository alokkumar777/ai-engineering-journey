# %%
def process_data(data):
  try:
    result = int(data)
    return result * 2
  except ValueError:
    print("Invaild")
    raise
  
try:
  process_data('abc')
except ValueError:
  print("Handled")
# Out:
# Invaild
# Handled

# %%
try:
  x = -1
  assert x > 0, "Cannot be negative"
except AssertionError as e:
  print(f"{e}")
# Out:
# Cannot be negative
